# %% [markdown]
# # 1、对数据集进行处理，转换成适合关联规则挖掘的形式

# %% [markdown]
# ## 在后文中选用Apriori算法进行关联规则挖掘。由于Apriori算法适用于对二值属性进行分析，因此在数据预处理阶段需要将原数据中的多值属性转换为二值属性。

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import math
data = pd.read_csv("/Users/liuhao/Desktop/数据挖掘/刘豪_3120191022/youtube-new/GBvideos.csv")
data.head()
# Out:
#       video_id trending_date  \
# 0  Jw1Y-zhQURU      17.14.11
# 1  3s1rvMFUweQ      17.14.11
# 2  n1WpP7iowLc      17.14.11
# 3  PUTEiSjKwJU      17.14.11
# 4  rHwDegptbI4      17.14.11
#
#                                                title  \
# 0      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1          Taylor Swift: …Ready for It? (Live) - SNL
# 2         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3  Goals from Salford City vs Class of 92 and Fri...
# 4  Dashcam captures truck's near miss with child ...
#
#                 channel_title  category_id              publish_time  \
# 0                  John Lewis           26  2017-11-10T07:38:29.000Z
# 1         Saturday Night Live           24  2017-11-12T06:24:44.000Z
# 2                  EminemVEVO           10  2017-11-10T17:00:03.000Z
# 3  Salford City Football Club           17  2017-11-13T02:30:38.000Z
# 4            Cute Girl Videos           25  2017-11-13T01:45:13.000Z
#
#                                                 tags     views   likes  \
# 0  christmas|"john lewis christmas"|"john lewis"|...   7224515   55681
# 1  SNL|"Saturday Night Live"|"SNL Season 43"|"Epi...   1053632   25561
# 2  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579  787420
# 3  Salford City FC|"Salford City"|"Salford"|"Clas...     27833     193
# 4                                             [none]      9815      30
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0     10247           9479  https://i.ytimg.com/vi/Jw1Y-zhQURU/default.jpg
# 1      2294           2757  https://i.ytimg.com/vi/3s1rvMFUweQ/default.jpg
# 2     43420         125882  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 3        12             37  https://i.ytimg.com/vi/PUTEiSjKwJU/default.jpg
# 4         2             30  https://i.ytimg.com/vi/rHwDegptbI4/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          description
# 0  Click here to continue the story and make your...
# 1  Musical guest Taylor Swift performs …Ready for...
# 2  Eminem's new track Walk on Water ft. Beyoncé i...
# 3  Salford drew 4-4 against the Class of 92 and F...
# 4  Dashcam captures truck's near miss with child ...

# %% [markdown]
# ## 原数据集一共含有16个属性，考虑到数据转换的复杂程度，这里选取了8列具有分析价值的进行关联规则挖掘，分别为：publish_time 、views、likes、dislikes、comment_count、comments_disabled、ratings_disabled、video_error_or_removed。之后附加上category_id作为标识。其余属性为文本信息，不具有挖掘价值。
# ## 因为要将多值属性表示成二值，经过多方了解，采用如下转换策略：
# ### （1）对于publish_time 属性，大体上分布在2017年和2018年（有极少数的其他时间，忽略不计），所以这里发布时间为2017年的用‘0’表示， 发布时间为2018年的用‘1’表示；
# ### （2）views、likes、dislikes、comment_count四个属性均为连续型数值属性，根据其分布特点，选择将大于其‘中位数’的值表示为‘1’，小于其‘中位数’的值表示为‘0’；
# ### （3）comments_disabled、ratings_disabled、video_error_or_removed分别为三个布尔属性，因为绝大多数值为False,为了防止矩阵过于稀疏，这里将取False的值表示为‘1’，取True的值表示为‘0’；
# ### （4）category_id为连续型数值属性，因为此属性较为关键，且值所分布的范围较小，所以没有同（2）进行相同的处理，而是单独处理。category_id的值分布在1至43之间，且大多持集中在15~25的区间内，所以这里将其划分为三个区间，分别为1至15、 15至25、 25至43，并分别用三个二值字段category_id_1、 category_id_2、 category_id_3表示（原来的category_id删掉）。 代码如下：

# %%
data['publish_time'] = np.where(data['publish_time'].str.match('2017'),0,1)

for col in ('views','likes','dislikes','comment_count'):
    data[col] = np.where(data[col] < data[col].median(),0,1)

for col in ('comments_disabled','ratings_disabled','video_error_or_removed'):
    data[col] = np.where(data[col]==False,1,0)

data['category_id_1']=np.where(data['category_id'] <= 15,1,0)
data['category_id_2']=np.where(((data['category_id'] > 15) & (data['category_id'] <= 25)),1,0)
data['category_id_3']=np.where(data['category_id'] > 25,1,0)

data_bool = data[['video_id','publish_time', 'views', 'likes', 'dislikes', 'comment_count', 'comments_disabled', 'ratings_disabled',
            'video_error_or_removed','category_id_1','category_id_2','category_id_3']]
data_bool.head()
# Out:
#       video_id  publish_time  views  likes  dislikes  comment_count  \
# 0  Jw1Y-zhQURU             0      1      1         1              1
# 1  3s1rvMFUweQ             0      1      1         1              1
# 2  n1WpP7iowLc             0      1      1         1              1
# 3  PUTEiSjKwJU             0      0      0         0              0
# 4  rHwDegptbI4             0      0      0         0              0
#
#    comments_disabled  ratings_disabled  video_error_or_removed  category_id_1  \
# 0                  1                 1                       1              0
# 1                  1                 1                       1              0
# 2                  1                 1                       1              1
# 3                  1                 1                       1              0
# 4                  1                 1                       1              0
#
#    category_id_2  category_id_3
# 0              0              1
# 1              1              0
# 2              0              0
# 3              1              0
# 4              1              0

# %% [markdown]
# # 2、找出频繁模式

# %% [markdown]
# ## 支持度为0.3，置信度为0.8
# ### 进行第一次挖掘，找到L_1项集

# %%
def preProcessing(data, vote_1_0):
    '''
    数据预处理
    以按 1 或 0 寻找关联规则
    '''
    data_pre = []
    for index, row in data.iterrows():
        tmp_data = []
        #print(row)
        for i in range(1, len(row)):

            if (row[i] == vote_1_0):
                tmp_data.append(data.columns.values.tolist()[i])

        if (tmp_data == []):
            continue
        data_pre.append(tmp_data)
    return data_pre

def mining_first(data, support, confidence):
    '''
    进行第一次挖掘
    挖掘候选1-项集
    '''
    dic = {}
    count = len(data)
    for data_line in data:
        for data_item in data_line:
            if (data_item in dic):
                dic[data_item] += 1
            else:
                dic[data_item] = 1

    assert (support >= 0) and (support <= 1), 'support must be in 0-1'
    val_support = int(count * support)
    assert (confidence >= 0) and (confidence <= 1), 'confidence must be in 0-1'
    dic_1 = {}
    for item in dic:
        if (dic[item] >= val_support):
            dic_1[item] = dic[item]

    return dic_1

# 支持度
support = 0.3
# 置信度
confidence = 0.8
data_1 = preProcessing(data_bool, 1) #按照1寻找关联规则
dic_1 = mining_first(data_1, support, confidence)
print('L_1项集：')
print(dic_1)
# Out:
# L_1项集：
# {'views': 19458, 'likes': 19458, 'dislikes': 19459, 'comment_count': 19459, 'comments_disabled': 38233, 'ratings_disabled': 38644, 'video_error_or_removed': 38847, 'category_id_2': 18894, 'category_id_1': 17009, 'publish_time': 27879}

# %% [markdown]
# ### 进行第二次挖掘，找到L_2项集

# %%
def mining_second(data, dic_before, support, confidence):
    '''
    进行关联规则的二次挖掘
    挖掘出候选2-项集
    '''
    dic = {}
    count = len(data)
    count2 = 0
    for data_line in data:
        # 获取元素数量
        count_item = len(data_line)
        # 每两个组合计数
        for i in range(0, count_item - 1):
            for j in range(i + 1, count_item):
                if (data_line[i] in dic_before and data_line[j] in dic_before):
                    count2 += 1
                    tmp = (data_line[i], data_line[j])
                    if (tmp in dic):
                        dic[tmp] += 1
                    else:
                        dic[tmp] = 1
                else:
                    continue
    # print(dic)
    assert (support >= 0) and (support <= 1), 'support must be in 0-1'
    assert (confidence >= 0) and (confidence <= 1), 'confidence must be in 0-1'

    dic_2 = {}
    for item in dic:
        count_item0 = dic_before[item[0]]
        count_item1 = dic_before[item[1]]
        # 判断 支持度 和 置信度
        if ((dic[item] >= support * count) and (
                (dic[item] >= confidence * count_item0) or (dic[item] >= confidence * count_item1))):
            dic_2[item] = dic[item]

    return dic_2

dic_2 = mining_second(data_1, dic_1, support, confidence)
print('L_2项集：')
print(dic_2)
# Out:
# L_2项集：
# {('views', 'likes'): 17145, ('views', 'dislikes'): 16748, ('views', 'comment_count'): 16055, ('views', 'comments_disabled'): 19073, ('views', 'ratings_disabled'): 19286, ('views', 'video_error_or_removed'): 19397, ('likes', 'dislikes'): 16222, ('likes', 'comment_count'): 16758, ('likes', 'comments_disabled'): 19295, ('likes', 'ratings_disabled'): 19458, ('likes', 'video_error_or_removed'): 19406, ('dislikes', 'comment_count'): 16500, ('dislikes', 'comments_disabled'): 19182, ('dislikes', 'ratings_disabled'): 19459, ('dislikes', 'video_error_or_removed'): 19409, ('comment_count', 'comments_disabled'): 19459, ('comment_count', 'ratings_disabled'): 19447, ('comment_count', 'video_error_or_removed'): 19416, ('comments_disabled', 'ratings_disabled'): 38185, ('comments_disabled', 'video_error_or_removed'): 38164, ('ratings_disabled', 'video_error_or_removed'): 38575, ('comments_disabled', 'category_id_2'): 18408, ('ratings_disabled', 'category_id_2'): 18780, ('video_error_or_removed', 'category_id_2'): 18859, ('comments_disabled', 'category_id_1'): 16860, ('ratings_disabled', 'category_id_1'): 16859, ('video_error_or_removed', 'category_id_1'): 16975, ('publish_time', 'comments_disabled'): 27396, ('publish_time', 'ratings_disabled'): 27703, ('publish_time', 'video_error_or_removed'): 27810, ('publish_time', 'views'): 16069, ('publish_time', 'dislikes'): 15698, ('publish_time', 'likes'): 15777}

# %% [markdown]
# ### 进行第三次挖掘，找到L_3项集或者L_4项集至L_n项集，最后一个项集为空

# %%
def mining_third(data, dic_before, support, confidencecoincidence):
    '''
    进行关联规则的三次挖掘
    挖掘出候选3-项集或者4-项集乃至n-项集
    '''
    dic_3 = {}
    for item0 in dic_before:
        for item1 in dic_before:
            if (item0 != item1):
                # print(item0,item1)
                item_len = len(item0)
                equal = True
                tmp_item3 = []
                # 判断前n-1项是否一致
                for i in range(item_len - 1):
                    tmp_item3.append(item0[i])
                    if (item0[i] != item1[i]):
                        equal = False
                        break
                if (equal == True):
                    minitem = min(item0[-1], item1[-1])
                    maxitem = max(item0[-1], item1[-1])
                    tmp_item3.append(minitem)
                    tmp_item3.append(maxitem)
                    tmp_item3 = tuple(tmp_item3)
                    dic_3[tmp_item3] = 0
                else:
                    continue
    # print('dic_3:',dic_3)
    for data_line in data:
        for item in dic_3:
            is_in = True
            for i in range(len(item)):
                if (item[i] not in data_line):
                    is_in = False

            if (is_in == True):
                dic_3[item] += 1

    assert (support >= 0) and (support <= 1), 'support must be in 0-1'
    assert (confidencecoincidence >= 0) and (confidence <= 1), 'confidence must be in 0-1'

    count = len(data)
    dic_3n = {}
    for item in dic_3:
        count_item0 = dic_before[item[:-1]]
        # 判断 支持度 和 置信度
        if ((dic_3[item] >= support * count) and (dic_3[item] >= confidence * count_item0)):
            dic_3n[item] = dic_3[item]

    return dic_3n
    pass

dic_r = []
n = 3
while (dic_2 != {}):
    dic_r.append(dic_2)
    dic_3 = mining_third(data_1, dic_2, support, confidence)
    dic_2 = dic_3
    print('L_{}项集：'.format(n))
    print(dic_2)
    n = n+1
# Out:
# L_3项集：
# {('views', 'dislikes', 'likes'): 15498, ('views', 'comment_count', 'likes'): 15189, ('views', 'comments_disabled', 'likes'): 16984, ('views', 'likes', 'ratings_disabled'): 17145, ('views', 'likes', 'video_error_or_removed'): 17100, ('views', 'comment_count', 'dislikes'): 14890, ('views', 'comments_disabled', 'dislikes'): 16555, ('views', 'dislikes', 'ratings_disabled'): 16748, ('views', 'dislikes', 'video_error_or_removed'): 16698, ('views', 'comment_count', 'comments_disabled'): 16055, ('views', 'comment_count', 'ratings_disabled'): 16045, ('views', 'comment_count', 'video_error_or_removed'): 16019, ('views', 'comments_disabled', 'ratings_disabled'): 19063, ('views', 'comments_disabled', 'video_error_or_removed'): 19012, ('views', 'ratings_disabled', 'video_error_or_removed'): 19225, ('likes', 'comment_count', 'dislikes'): 14815, ('likes', 'comments_disabled', 'dislikes'): 16082, ('likes', 'dislikes', 'ratings_disabled'): 16222, ('likes', 'dislikes', 'video_error_or_removed'): 16187, ('likes', 'comment_count', 'comments_disabled'): 16758, ('likes', 'comment_count', 'ratings_disabled'): 16758, ('likes', 'comment_count', 'video_error_or_removed'): 16715, ('likes', 'comments_disabled', 'ratings_disabled'): 19295, ('likes', 'comments_disabled', 'video_error_or_removed'): 19243, ('likes', 'ratings_disabled', 'video_error_or_removed'): 19406, ('dislikes', 'comment_count', 'comments_disabled'): 16500, ('dislikes', 'comment_count', 'ratings_disabled'): 16500, ('dislikes', 'comment_count', 'video_error_or_removed'): 16472, ('dislikes', 'comments_disabled', 'ratings_disabled'): 19182, ('dislikes', 'comments_disabled', 'video_error_or_removed'): 19132, ('dislikes', 'ratings_disabled', 'video_error_or_removed'): 19409, ('comment_count', 'comments_disabled', 'ratings_disabled'): 19447, ('comment_count', 'comments_disabled', 'video_error_or_removed'): 19416, ('comment_count', 'ratings_disabled', 'video_error_or_removed'): 19404, ('comments_disabled', 'ratings_disabled', 'video_error_or_removed'): 38116, ('comments_disabled', 'category_id_2', 'ratings_disabled'): 18389, ('comments_disabled', 'category_id_1', 'ratings_disabled'): 16831, ('comments_disabled', 'category_id_2', 'video_error_or_removed'): 18373, ('comments_disabled', 'category_id_1', 'video_error_or_removed'): 16826, ('ratings_disabled', 'category_id_2', 'video_error_or_removed'): 18745, ('ratings_disabled', 'category_id_1', 'video_error_or_removed'): 16825, ('publish_time', 'comments_disabled', 'ratings_disabled'): 27380, ('publish_time', 'comments_disabled', 'video_error_or_removed'): 27327, ('publish_time', 'ratings_disabled', 'video_error_or_removed'): 27634, ('publish_time', 'dislikes', 'ratings_disabled'): 15698, ('publish_time', 'likes', 'ratings_disabled'): 15777, ('publish_time', 'dislikes', 'video_error_or_removed'): 15648, ('publish_time', 'likes', 'video_error_or_removed'): 15725, ('publish_time', 'dislikes', 'views'): 13912, ('publish_time', 'likes', 'views'): 14196, ('publish_time', 'dislikes', 'likes'): 13411}
# L_4项集：
# {('views', 'dislikes', 'likes', 'ratings_disabled'): 15498, ('views', 'dislikes', 'likes', 'video_error_or_removed'): 15463, ('views', 'comment_count', 'dislikes', 'likes'): 14180, ('views', 'comment_count', 'comments_disabled', 'likes'): 15189, ('views', 'comment_count', 'likes', 'ratings_disabled'): 15189, ('views', 'comment_count', 'likes', 'video_error_or_removed'): 15153, ('views', 'comments_disabled', 'dislikes', 'likes'): 15358, ('views', 'comments_disabled', 'likes', 'ratings_disabled'): 16984, ('views', 'comments_disabled', 'likes', 'video_error_or_removed'): 16939, ('views', 'likes', 'ratings_disabled', 'video_error_or_removed'): 17100, ('views', 'comment_count', 'comments_disabled', 'dislikes'): 14890, ('views', 'comment_count', 'dislikes', 'ratings_disabled'): 14890, ('views', 'comment_count', 'dislikes', 'video_error_or_removed'): 14862, ('views', 'comments_disabled', 'dislikes', 'ratings_disabled'): 16555, ('views', 'comments_disabled', 'dislikes', 'video_error_or_removed'): 16505, ('views', 'dislikes', 'ratings_disabled', 'video_error_or_removed'): 16698, ('views', 'comment_count', 'comments_disabled', 'ratings_disabled'): 16045, ('views', 'comment_count', 'comments_disabled', 'video_error_or_removed'): 16019, ('views', 'comment_count', 'ratings_disabled', 'video_error_or_removed'): 16009, ('views', 'comments_disabled', 'ratings_disabled', 'video_error_or_removed'): 19002, ('likes', 'comment_count', 'comments_disabled', 'dislikes'): 14815, ('likes', 'comment_count', 'dislikes', 'ratings_disabled'): 14815, ('likes', 'comment_count', 'dislikes', 'video_error_or_removed'): 14787, ('likes', 'comments_disabled', 'dislikes', 'ratings_disabled'): 16082, ('likes', 'comments_disabled', 'dislikes', 'video_error_or_removed'): 16047, ('likes', 'dislikes', 'ratings_disabled', 'video_error_or_removed'): 16187, ('likes', 'comment_count', 'comments_disabled', 'ratings_disabled'): 16758, ('likes', 'comment_count', 'comments_disabled', 'video_error_or_removed'): 16715, ('likes', 'comment_count', 'ratings_disabled', 'video_error_or_removed'): 16715, ('likes', 'comments_disabled', 'ratings_disabled', 'video_error_or_removed'): 19243, ('dislikes', 'comment_count', 'comments_disabled', 'ratings_disabled'): 16500, ('dislikes', 'comment_count', 'comments_disabled', 'video_error_or_removed'): 16472, ('dislikes', 'comment_count', 'ratings_disabled', 'video_error_or_removed'): 16472, ('dislikes', 'comments_disabled', 'ratings_disabled', 'video_error_or_removed'): 19132, ('comment_count', 'comments_disabled', 'ratings_disabled', 'video_error_or_removed'): 19404, ('comments_disabled', 'category_id_2', 'ratings_disabled', 'video_error_or_removed'): 18354, ('comments_disabled', 'category_id_1', 'ratings_disabled', 'video_error_or_removed'): 16797, ('publish_time', 'comments_disabled', 'ratings_disabled', 'video_error_or_removed'): 27311, ('publish_time', 'dislikes', 'ratings_disabled', 'video_error_or_removed'): 15648, ('publish_time', 'dislikes', 'ratings_disabled', 'views'): 13912, ('publish_time', 'dislikes', 'likes', 'ratings_disabled'): 13411, ('publish_time', 'likes', 'ratings_disabled', 'video_error_or_removed'): 15725, ('publish_time', 'likes', 'ratings_disabled', 'views'): 14196, ('publish_time', 'dislikes', 'video_error_or_removed', 'views'): 13862, ('publish_time', 'dislikes', 'likes', 'video_error_or_removed'): 13376, ('publish_time', 'likes', 'video_error_or_removed', 'views'): 14151, ('publish_time', 'dislikes', 'likes', 'views'): 12924}
# L_5项集：
# {('views', 'dislikes', 'likes', 'ratings_disabled', 'video_error_or_removed'): 15463, ('views', 'comment_count', 'dislikes', 'likes', 'ratings_disabled'): 14180, ('views', 'comment_count', 'dislikes', 'likes', 'video_error_or_removed'): 14152, ('views', 'comment_count', 'comments_disabled', 'dislikes', 'likes'): 14180, ('views', 'comment_count', 'comments_disabled', 'likes', 'ratings_disabled'): 15189, ('views', 'comment_count', 'comments_disabled', 'likes', 'video_error_or_removed'): 15153, ('views', 'comment_count', 'likes', 'ratings_disabled', 'video_error_or_removed'): 15153, ('views', 'comments_disabled', 'dislikes', 'likes', 'ratings_disabled'): 15358, ('views', 'comments_disabled', 'dislikes', 'likes', 'video_error_or_removed'): 15323, ('views', 'comments_disabled', 'likes', 'ratings_disabled', 'video_error_or_removed'): 16939, ('views', 'comment_count', 'comments_disabled', 'dislikes', 'ratings_disabled'): 14890, ('views', 'comment_count', 'comments_disabled', 'dislikes', 'video_error_or_removed'): 14862, ('views', 'comment_count', 'dislikes', 'ratings_disabled', 'video_error_or_removed'): 14862, ('views', 'comments_disabled', 'dislikes', 'ratings_disabled', 'video_error_or_removed'): 16505, ('views', 'comment_count', 'comments_disabled', 'ratings_disabled', 'video_error_or_removed'): 16009, ('likes', 'comment_count', 'comments_disabled', 'dislikes', 'ratings_disabled'): 14815, ('likes', 'comment_count', 'comments_disabled', 'dislikes', 'video_error_or_removed'): 14787, ('likes', 'comment_count', 'dislikes', 'ratings_disabled', 'video_error_or_removed'): 14787, ('likes', 'comments_disabled', 'dislikes', 'ratings_disabled', 'video_error_or_removed'): 16047, ('likes', 'comment_count', 'comments_disabled', 'ratings_disabled', 'video_error_or_removed'): 16715, ('dislikes', 'comment_count', 'comments_disabled', 'ratings_disabled', 'video_error_or_removed'): 16472, ('publish_time', 'dislikes', 'ratings_disabled', 'video_error_or_removed', 'views'): 13862, ('publish_time', 'dislikes', 'likes', 'ratings_disabled', 'video_error_or_removed'): 13376, ('publish_time', 'dislikes', 'likes', 'ratings_disabled', 'views'): 12924, ('publish_time', 'likes', 'ratings_disabled', 'video_error_or_removed', 'views'): 14151, ('publish_time', 'dislikes', 'likes', 'video_error_or_removed', 'views'): 12889}
# L_6项集：
# {('views', 'comment_count', 'dislikes', 'likes', 'ratings_disabled', 'video_error_or_removed'): 14152, ('views', 'comment_count', 'comments_disabled', 'dislikes', 'likes', 'ratings_disabled'): 14180, ('views', 'comment_count', 'comments_disabled', 'dislikes', 'likes', 'video_error_or_removed'): 14152, ('views', 'comment_count', 'comments_disabled', 'likes', 'ratings_disabled', 'video_error_or_removed'): 15153, ('views', 'comments_disabled', 'dislikes', 'likes', 'ratings_disabled', 'video_error_or_removed'): 15323, ('views', 'comment_count', 'comments_disabled', 'dislikes', 'ratings_disabled', 'video_error_or_removed'): 14862, ('likes', 'comment_count', 'comments_disabled', 'dislikes', 'ratings_disabled', 'video_error_or_removed'): 14787, ('publish_time', 'dislikes', 'likes', 'ratings_disabled', 'video_error_or_removed', 'views'): 12889}
# L_7项集：
# {('views', 'comment_count', 'comments_disabled', 'dislikes', 'likes', 'ratings_disabled', 'video_error_or_removed'): 14152}
# L_8项集：
# {}

# %% [markdown]
# # 3、导出关联规则，计算其支持度和置信度，并用lift和cosine对规则进行评价；对挖掘结果进行初步分析

# %%
#自定义连接函数，用于实现L_{k-1}到C_k的连接
def connect_string(x, ms):
    x = list(map(lambda i:sorted(i.split(ms)), x))
    l = len(x[0])
    r = []
    for i in range(len(x)):
        for j in range(i,len(x)):
            if x[i][:l-1] == x[j][:l-1] and x[i][l-1] != x[j][l-1]:
                r.append(x[i][:l-1]+sorted([x[j][l-1],x[i][l-1]]))
    return r


# 寻找关联规则的函数
def find_rule(d, support, confidence,ms= u'-->'):
    import time
    start = time.perf_counter()
    result = pd.DataFrame(index=['support', 'confidence','lift','cosine'])  # 定义输出结果
    col_name= d.columns.values.tolist()
    support_series = pd.Series(map(lambda x: x/len(d), 1.0*d.sum()),index=col_name)  # 支持度序列
    #print(support_series)
    column = list(support_series[support_series > support].index)  # 初步根据支持度筛选
    #print(column)
    k = 0
    while len(column) > 1:
        k = k + 1
        print(u'\n正在寻找候选%s项集...' % (k+1))
        column = connect_string(column, ms)
        print(u'数目：%s...' % len(column))
        sf = lambda i: d[i].prod(axis=1, numeric_only=True)  # 新一批支持度的计算函数

        # 创建连接数据
        d_2 = pd.DataFrame(list(map(sf, column)), index=[ms.join(i) for i in column]).T
        col_name_2=d_2.columns.values.tolist()

        support_series_2 = pd.Series(map(lambda x: x / len(d),1.0 * d_2[[ms.join(i) for i in column]].sum()),index=col_name_2)  # 计算连接后的支持度
        #print(support_series_2)
        column = list(support_series_2[support_series_2 > support].index)  # 新一轮支持度筛选
        #print(column)
        support_series = support_series.append(support_series_2)
        #print(support_series)
        column2 = []

        for i in column:  # 遍历可能的推理
            i = i.split(ms)
            for j in range(len(i)):
                column2.append(i[:j] + i[j + 1:] + i[j:j + 1])
        #print(column2)

        cofidence_series = pd.Series(index=[ms.join(i) for i in column2])  # 定义置信度序列
        lift_series = pd.Series(index=[ms.join(i) for i in column2])
        cosine_series = pd.Series(index=[ms.join(i) for i in column2])
        #print(cofidence_series)

        for i in column2:  # 计算置信度序列
            #print(i)
            cofidence_series[ms.join(i)] = support_series[ms.join(sorted(i))] / support_series[ms.join(i[:len(i) - 1])]
            lift_series[ms.join(i)] = cofidence_series[ms.join(i)] / support_series[i[-1]]
            cosine_series[ms.join(i)] = support_series[ms.join(sorted(i))] / math.sqrt(support_series[ms.join(i[:len(i) - 1])]*support_series[i[-1]])
            


        for i in cofidence_series[cofidence_series > confidence].index:  # 置信度筛选
            result[i] = 0.0
            result[i]['confidence'] = cofidence_series[i]
            result[i]['support'] = support_series[ms.join(sorted(i.split(ms)))]
            result[i]['lift'] = lift_series[i]
            result[i]['cosine'] = cosine_series[i]

    result = result.T.sort_values(['confidence', 'support','lift','cosine'], ascending=False)  # 结果整理，输出
    end = time.perf_counter()
    print(u'\n搜索完成，用时：%0.2f秒' % (end - start))
    print(u'\n结果为：')
    print(result)
    return result

used_data_bool = data[['publish_time', 'views', 'likes', 'dislikes', 'comment_count', 'comments_disabled', 'ratings_disabled',
            'video_error_or_removed','category_id_1','category_id_2','category_id_3']]
result = find_rule(used_data_bool,support,confidence,'-->')#最小置信度和支持度维持原数
result
# Out:
# 正在寻找候选2项集...
# 数目：45...
#
# 正在寻找候选3项集...
# 数目：72...
#
# 正在寻找候选4项集...
# 数目：82...
#
# 正在寻找候选5项集...
# 数目：59...
#
# 正在寻找候选6项集...
# 数目：28...
#
# 正在寻找候选7项集...
# 数目：8...
#
# 正在寻找候选8项集...
# 数目：1...
#
# 搜索完成，用时：10.32秒
#
# 结果为：
#                                                      support  confidence  \
# comment_count-->comments_disabled                   0.500026    1.000000
# dislikes-->ratings_disabled                         0.500026    1.000000
# likes-->ratings_disabled                            0.500000    1.000000
# comment_count-->ratings_disabled-->comments_dis...  0.499717    1.000000
# comment_count-->video_error_or_removed-->commen...  0.498921    1.000000
# ...                                                      ...         ...
# dislikes-->ratings_disabled-->publish_time          0.403382    0.806722
# comments_disabled-->dislikes-->video_error_or_r...  0.396521    0.806554
# comments_disabled-->dislikes-->ratings_disabled...  0.396521    0.806554
# dislikes-->video_error_or_removed-->publish_time    0.402097    0.806224
# dislikes-->ratings_disabled-->video_error_or_re...  0.402097    0.806224
#
#                                                         lift    cosine
# comment_count-->comments_disabled                   1.017864  0.713413
# dislikes-->ratings_disabled                         1.007039  0.709609
# likes-->ratings_disabled                            1.007039  0.709591
# comment_count-->ratings_disabled-->comments_dis...  1.017864  0.713193
# comment_count-->video_error_or_removed-->commen...  1.017864  0.712624
# ...                                                      ...       ...
# dislikes-->ratings_disabled-->publish_time          1.126094  0.673978
# comments_disabled-->dislikes-->video_error_or_r...  1.125861  0.668152
# comments_disabled-->dislikes-->ratings_disabled...  1.125861  0.668152
# dislikes-->video_error_or_removed-->publish_time    1.125399  0.672696
# dislikes-->ratings_disabled-->video_error_or_re...  1.125399  0.672696
#
# [1001 rows x 4 columns]
#                                                      support  confidence  \
# comment_count-->comments_disabled                   0.500026    1.000000
# dislikes-->ratings_disabled                         0.500026    1.000000
# likes-->ratings_disabled                            0.500000    1.000000
# comment_count-->ratings_disabled-->comments_dis...  0.499717    1.000000
# comment_count-->video_error_or_removed-->commen...  0.498921    1.000000
# ...                                                      ...         ...
# dislikes-->ratings_disabled-->publish_time          0.403382    0.806722
# comments_disabled-->dislikes-->video_error_or_r...  0.396521    0.806554
# comments_disabled-->dislikes-->ratings_disabled...  0.396521    0.806554
# dislikes-->video_error_or_removed-->publish_time    0.402097    0.806224
# dislikes-->ratings_disabled-->video_error_or_re...  0.402097    0.806224
#
#                                                         lift    cosine
# comment_count-->comments_disabled                   1.017864  0.713413
# dislikes-->ratings_disabled                         1.007039  0.709609
# likes-->ratings_disabled                            1.007039  0.709591
# comment_count-->ratings_disabled-->comments_dis...  1.017864  0.713193
# comment_count-->video_error_or_removed-->commen...  1.017864  0.712624
# ...                                                      ...       ...
# dislikes-->ratings_disabled-->publish_time          1.126094  0.673978
# comments_disabled-->dislikes-->video_error_or_r...  1.125861  0.668152
# comments_disabled-->dislikes-->ratings_disabled...  1.125861  0.668152
# dislikes-->video_error_or_removed-->publish_time    1.125399  0.672696
# dislikes-->ratings_disabled-->video_error_or_re...  1.125399  0.672696
#
# [1001 rows x 4 columns]

# %% [markdown]
# ## 分析：通过lift 和cosine进行评价后发现，不是每个规则都是有趣的，因此，根据lift 和cosine两个指标对规则进行了过滤，结果如下：

# %%
result_interest=pd.DataFrame(result[(result.lift > 1.6) & (result.cosine < 0.7)])
print(result_interest)
# Out:
# Empty DataFrame
# Columns: [support, confidence, lift, cosine]
# Index: []

# %% [markdown]
# ## 分析：可见，数据量大大减少，为我们的进一步分析提供了便利

# %% [markdown]
# # 4、对挖掘结果进行进一步分析和可视化展示

# %%
result.plot.scatter(x='support', y='lift')
plt.show()

# %% [markdown]
# ## 分析“support”与“lift”之间的分布关系：发现 lift 较高的规则分布在 support 较低的位置

# %%
result.plot.scatter(x='confidence', y='lift')
plt.show()

# %% [markdown]
# ## 分析“confidence”与“lift”之间的分布关系：发现总体趋势是随着confidence的增大，lift也在增大

# %%
result.plot.scatter(x='support', y='cosine')
plt.show()

# %% [markdown]
# ## 分析“support”与“cosine”之间的分布关系：总体也有正相关的趋势

# %%
result.plot.scatter(x='confidence', y='cosine')
plt.show()

# %% [markdown]
# ## 分析“confidence”与“cosine”之间的分布关系：总体趋势较为离散，没有明显的线性关系
